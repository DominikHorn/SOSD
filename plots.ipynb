# %%
import pandas as pd
import json

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
fontsize=14

# %%
results_file = "results.csv"
df = pd.read_csv(results_file)

# %%
df["MiB"] = df["byte_size"] / 1024**2

# %%
df
# Out:
#                 name  variant  median_time   byte_size    build_time  \
# 0                RMI        0      182.742   402653216             0
# 1                RMI        1      187.532   201326608             0
# 2                RMI        2      195.728   100663312             0
# 3                RMI        3      239.658    41943040             0
# 4                RMI        4      219.693    12582928             0
# 5                RMI        5      217.271     6291472             0
# 6                RMI        6      247.152      786464             0
# 7                RMI        7      323.682       24608             0
# 8                RMI        8      396.776        6160             0
# 9                RMI        9      451.788        3088             0
# 10              MWHC        0      294.061   861000241  128376820548
# 11     CompactedMWHC        0      501.048   734602249  128305485095
# 12  SimpleHollowTrie        0     1042.310  1600000016   97098130998
# 13        HollowTrie        0     1527.990   294299152  261404211610
#
#         searcher            dataset          MiB
# 0   BinarySearch  books_200M_uint64   384.000031
# 1   BinarySearch  books_200M_uint64   192.000015
# 2   BinarySearch  books_200M_uint64    96.000015
# 3   BinarySearch  books_200M_uint64    40.000000
# 4   BinarySearch  books_200M_uint64    12.000015
# 5   BinarySearch  books_200M_uint64     6.000015
# 6   BinarySearch  books_200M_uint64     0.750031
# 7   BinarySearch  books_200M_uint64     0.023468
# 8   BinarySearch  books_200M_uint64     0.005875
# 9   BinarySearch  books_200M_uint64     0.002945
# 10  BinarySearch  books_200M_uint64   821.113816
# 11  BinarySearch  books_200M_uint64   700.571298
# 12  BinarySearch  books_200M_uint64  1525.878922
# 13  BinarySearch  books_200M_uint64   280.665543

# %%
def plot():
    fig, ax = plt.subplots(figsize=(6, 3))
#     ax.set_xlim(0, 8500)
#     ax.set_ylim(0, 550)
        
    for name, group in df.groupby(["name"]):
        ax.scatter(data=group, x="MiB", y="median_time", label=f"{name}", marker=True)
        
    ax.legend(labelspacing=0.1, borderpad=0.2, handlelength=1)
    
    ax.set_xlabel("Size (MiB)", fontsize=fontsize)
    ax.set_ylabel("Lookup Latency (ns)", fontsize=fontsize, x=0.05)
    
    fig.savefig("mmphf_experiment.png", bbox_inches="tight", dpi=300)

plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 16>()
#      12     ax.set_ylabel("Lookup Latency (ns)", fontsize=fontsize, x=0.05)
#      14     fig.savefig("mmphf_experiment.png", bbox_inches="tight", dpi=300)
# ---> 16 plot()
#
# Input In [6], in plot()
#       3 #     ax.set_xlim(0, 8500)
#       4 #     ax.set_ylim(0, 550)
#       6     for name, group in df.groupby(["name"]):
# ----> 7         ax.scatter(data=group, x="MiB", y="median_time", label=f"{name}" if err > 0 else name, marker=True)
#       9     ax.legend(labelspacing=0.1, borderpad=0.2, handlelength=1)
#      11     ax.set_xlabel("Size (MiB)", fontsize=fontsize)
#
# NameError: name 'err' is not defined
